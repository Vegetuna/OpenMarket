# %%
import pandas as pd

# %%
cols = pd.read_csv('../../data/통합데이터/VIF_최적화최종점수.csv')

# %%
cols
# Out:
#                    변수명       VIF
# 0    컨택건수_이용유도_청구서_B0M  9.749834
# 1             연체건수_R6M  9.748268
# 2       증감율_이용건수_신용_분기  9.735530
# 3      증감율_이용건수_일시불_분기  9.671022
# 4           연체입금원금_B2M  9.593935
# ..                 ...       ...
# 223        카드론잔액_최종경과월  1.190877
# 224             최종연체회차  1.185832
# 225      증감_RP건수_통신_전월  1.170175
# 226     증감율_이용금액_CA_전월  1.164532
# 227      증감_RP건수_교통_전월  1.160859
#
# [228 rows x 2 columns]

# %%
cols = cols.head(150)

# %%
cols['변수명']
# Out:
# 0      컨택건수_이용유도_청구서_B0M
# 1               연체건수_R6M
# 2         증감율_이용건수_신용_분기
# 3        증감율_이용건수_일시불_분기
# 4             연체입금원금_B2M
#              ...
# 145            일시상환론한도금액
# 146       변동률_잔액_일시불_B1M
# 147    컨택건수_이용유도_LMS_B0M
# 148       당사멤버쉽_방문월수_R6M
# 149          컨택건수_채권_B0M
# Name: 변수명, Length: 150, dtype: object
