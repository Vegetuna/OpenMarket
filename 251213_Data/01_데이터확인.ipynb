# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/통합데이터/Final_merged_all_data.csv')

# %%
df['이용금액대'].value_counts(normalize=True)
# Out:
# 이용금액대
# 09.미사용       0.211017
# 05.10만원-     0.190817
# 02.50만원+     0.184367
# 04.10만원+     0.145217
# 01.100만원+    0.142383
# 03.30만원+     0.126200
# Name: proportion, dtype: float64
