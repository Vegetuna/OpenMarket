# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# 1. 데이터 파일 경로 설정 (본인 환경에 맞게 수정!)
# 예: data_path = "./data/Final_merged_all_data.csv"
data_path = "Final_Selected_150_Features_SHAP_Priority.csv"

# 2. 전체 데이터 로드
df = pd.read_csv(data_path)

# 3. 선정된 150개 변수 리스트 불러오기
#
selected_features_df = pd.read_csv("Final_Selected_150_Features_SHAP_Priority.csv")
selected_features = selected_features_df['변수명'].tolist()

print(f"✅ 분석 준비 완료! 총 {len(selected_features)}개의 변수를 사용합니다.")
# Out:
# ✅ 분석 준비 완료! 총 150개의 변수를 사용합니다.
